# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
import joblib

# Load dataset
df = pd.read_csv("Laptop_price - dataset.csv")

# Input and Output
X = df.drop("Price (Euro)", axis=1)
y = df["Price (Euro)"]

# One-Hot Encode
X = pd.get_dummies(X)

# Save feature names
encoded_columns = X.columns.tolist()

# Scale only numeric columns
numeric_cols = X.select_dtypes(include=['int64', 'float64']).columns

scaler = StandardScaler()
X[numeric_cols] = scaler.fit_transform(X[numeric_cols])

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.33,
    random_state=42
)

# Train Model
model = LinearRegression()
model.fit(X_train, y_train)

# Save Files
joblib.dump(model, "LR_Laptop_price.pkl")
joblib.dump(scaler, "scaler_laptop.pkl")
joblib.dump(encoded_columns, "columns_laptop.pkl")

print("Saved Successfully")
# Out:
# Saved Successfully
# Index(['Inches', 'CPU_Frequency (GHz)', 'RAM (GB)', 'Weight (kg)'], dtype='str')
